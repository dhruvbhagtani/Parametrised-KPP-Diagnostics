# %%
import cartopy.crs as ccrs
import cosima_cookbook as cc
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cmocean as cm
from dask.distributed import Client
import matplotlib.path as mpath
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# Avoid the Runtime errors in true_divide encountered when trying to divide by zero
import warnings
warnings.filterwarnings('ignore', category = RuntimeWarning)

# matplotlib stuff:
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib
from mpl_toolkits.mplot3d import axes3d
# %matplotlib inline
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['lines.linewidth'] = 2.0

# %%
from dask.distributed import Client
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:37933' processes=4 threads=16, memory=68.72 GB>

# %%
db = '/scratch/x77/db6174/access-om2/archive/databases/cc_database_nostress_param_2.db'
session = cc.database.create_session(db)
expt = ['025deg_jra55_ryf_param_kpp3', '025deg_jra55_ryf_nostress_param_kpp']
name = ['Control', 'No-stress']

# %%
start_time = '1996-01-01'
end_time = '1999-12-31'

# %% [markdown]
# ## KPP Mixing Layer

# %%
hblt_cont = cc.querying.getvar(expt = expt[0], session = session, variable = 'hblt', frequency = '1 daily', ncfile = 'ocean-2d-hblt-1-daily-snap-ym_199%_01.nc')
hblt_pram = cc.querying.getvar(expt = expt[1], session = session, variable = 'hblt', frequency = '1 daily', ncfile = 'ocean-2d-hblt-1-daily-snap-ym_199%_01.nc')

area_t = cc.querying.getvar(expt=expt[1], variable='area_t', session=session, frequency='static', n=1)

area_t_NA = area_t.sel(xt_ocean = slice(-90,10)).sel(yt_ocean = slice(10,65))
area_t_NA = (xr.ufuncs.isfinite(hblt_cont)*area_t_NA).mean('time')

area_t_NP = area_t.sel(xt_ocean = slice(-250,-100)).sel(yt_ocean = slice(10,65))
area_t_NP = (xr.ufuncs.isfinite(hblt_cont)*area_t_NP).mean('time')

area_t_SA = area_t.sel(xt_ocean = slice(-70,20)).sel(yt_ocean = slice(-65,-10))
area_t_SA = (xr.ufuncs.isfinite(hblt_cont)*area_t_SA).mean('time')

area_t_SP = area_t.sel(xt_ocean = slice(-250,-80)).sel(yt_ocean = slice(-65,-10))
area_t_SP = (xr.ufuncs.isfinite(hblt_cont)*area_t_SP).mean('time')

# %%
hblt_cont_NA = (hblt_cont*area_t_NA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NA.sum(dim = ['yt_ocean','xt_ocean'])
hblt_pram_NA = (hblt_pram*area_t_NA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NA.sum(dim = ['yt_ocean','xt_ocean'])

hblt_cont_NP = (hblt_cont*area_t_NP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NP.sum(dim = ['yt_ocean','xt_ocean'])
hblt_pram_NP = (hblt_pram*area_t_NP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NP.sum(dim = ['yt_ocean','xt_ocean'])

hblt_cont_SA = (hblt_cont*area_t_SA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SA.sum(dim = ['yt_ocean','xt_ocean'])
hblt_pram_SA = (hblt_pram*area_t_SA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SA.sum(dim = ['yt_ocean','xt_ocean'])

hblt_cont_SP = (hblt_cont*area_t_SP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SP.sum(dim = ['yt_ocean','xt_ocean'])
hblt_pram_SP = (hblt_pram*area_t_SP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SP.sum(dim = ['yt_ocean','xt_ocean'])

# %%
fig, axes = plt.subplots(nrows = 4, figsize = (20,22))

hblt_cont_NA.sel(time = slice(start_time, end_time)).plot(ax = axes[0],label = name[0])
hblt_pram_NA.sel(time = slice(start_time, end_time)).plot(ax = axes[0],label = name[1])
axes[0].legend()
axes[0].set_title('KPP mixing layer - NA')

hblt_cont_NP.sel(time = slice(start_time, end_time)).plot(ax = axes[1],label = name[0])
hblt_pram_NP.sel(time = slice(start_time, end_time)).plot(ax = axes[1],label = name[1])
axes[1].legend()
axes[1].set_title('KPP mixing layer - NP')

hblt_cont_SA.sel(time = slice(start_time, end_time)).plot(ax = axes[2],label = name[0])
hblt_pram_SA.sel(time = slice(start_time, end_time)).plot(ax = axes[2],label = name[1])
axes[2].legend()
axes[2].set_title('KPP mixing layer - SA')

hblt_cont_SP.sel(time = slice(start_time, end_time)).plot(ax = axes[3],label = name[0])
hblt_pram_SP.sel(time = slice(start_time, end_time)).plot(ax = axes[3],label = name[1])
axes[3].legend()
axes[3].set_title('KPP mixing layer - SP')
# Out:
# Text(0.5, 1.0, 'KPP mixing layer - SP')

# %% [markdown]
# ## Surface temperature

# %%
temp_sfc_cont = cc.querying.getvar(expt = expt[0], session = session, variable = 'surface_temp', frequency = '1 daily', 
                                   ncfile = 'ocean-2d-surface_temp-1-daily-mean-ym_199%_01.nc')
temp_sfc_pram = cc.querying.getvar(expt = expt[1], session = session, variable = 'surface_temp', frequency = '1 daily', 
                                   ncfile = 'ocean-2d-surface_temp-1-daily-mean-ym_199%_01.nc')

# %%
temp_cont_NA = (temp_sfc_cont*area_t_NA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NA.sum(dim = ['yt_ocean','xt_ocean'])
temp_pram_NA = (temp_sfc_pram*area_t_NA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NA.sum(dim = ['yt_ocean','xt_ocean'])

temp_cont_NP = (temp_sfc_cont*area_t_NP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NP.sum(dim = ['yt_ocean','xt_ocean'])
temp_pram_NP = (temp_sfc_pram*area_t_NP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NP.sum(dim = ['yt_ocean','xt_ocean'])

temp_cont_SA = (temp_sfc_cont*area_t_SA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SA.sum(dim = ['yt_ocean','xt_ocean'])
temp_pram_SA = (temp_sfc_pram*area_t_SA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SA.sum(dim = ['yt_ocean','xt_ocean'])

temp_cont_SP = (temp_sfc_cont*area_t_SP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SP.sum(dim = ['yt_ocean','xt_ocean'])
temp_pram_SP = (temp_sfc_pram*area_t_SP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SP.sum(dim = ['yt_ocean','xt_ocean'])

# %%
fig, axes = plt.subplots(nrows = 4, figsize = (20,22))

temp_cont_NA.sel(time = slice(start_time, end_time)).plot(ax = axes[0],label = name[0])
temp_pram_NA.sel(time = slice(start_time, end_time)).plot(ax = axes[0],label = name[1])
axes[0].legend()
axes[0].set_title('Surface temperature - NA')

temp_cont_NP.sel(time = slice(start_time, end_time)).plot(ax = axes[1],label = name[0])
temp_pram_NP.sel(time = slice(start_time, end_time)).plot(ax = axes[1],label = name[1])
axes[1].legend()
axes[1].set_title('Surface temperature - NP')

temp_cont_SA.sel(time = slice(start_time, end_time)).plot(ax = axes[2],label = name[0])
temp_pram_SA.sel(time = slice(start_time, end_time)).plot(ax = axes[2],label = name[1])
axes[2].legend()
axes[2].set_title('Surface temperature - SA')

temp_cont_SP.sel(time = slice(start_time, end_time)).plot(ax = axes[3],label = name[0])
temp_pram_SP.sel(time = slice(start_time, end_time)).plot(ax = axes[3],label = name[1])
axes[3].legend()
axes[3].set_title('Surface temperature - SP')
# Out:
# Text(0.5, 1.0, 'Surface temperature - SP')

# %% [markdown]
# ## Surface salinity

# %%
salt_sfc_cont = cc.querying.getvar(expt = expt[0], session = session, variable = 'surface_salt', frequency = '1 daily', 
                                   ncfile = 'ocean-2d-surface_salt-1-daily-mean-ym_199%_01.nc')
salt_sfc_pram = cc.querying.getvar(expt = expt[1], session = session, variable = 'surface_salt', frequency = '1 daily', 
                                   ncfile = 'ocean-2d-surface_salt-1-daily-mean-ym_199%_01.nc')

# %%
salt_cont_NA = (salt_sfc_cont*area_t_NA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NA.sum(dim = ['yt_ocean','xt_ocean'])
salt_pram_NA = (salt_sfc_pram*area_t_NA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NA.sum(dim = ['yt_ocean','xt_ocean'])

salt_cont_NP = (salt_sfc_cont*area_t_NP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NP.sum(dim = ['yt_ocean','xt_ocean'])
salt_pram_NP = (salt_sfc_pram*area_t_NP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NP.sum(dim = ['yt_ocean','xt_ocean'])

salt_cont_SA = (salt_sfc_cont*area_t_SA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SA.sum(dim = ['yt_ocean','xt_ocean'])
salt_pram_SA = (salt_sfc_pram*area_t_SA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SA.sum(dim = ['yt_ocean','xt_ocean'])

salt_cont_SP = (salt_sfc_cont*area_t_SP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SP.sum(dim = ['yt_ocean','xt_ocean'])
salt_pram_SP = (salt_sfc_pram*area_t_SP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SP.sum(dim = ['yt_ocean','xt_ocean'])

# %%
fig, axes = plt.subplots(nrows = 4, figsize = (20,22))

salt_cont_NA.sel(time = slice(start_time, end_time)).plot(ax = axes[0],label = name[0])
salt_pram_NA.sel(time = slice(start_time, end_time)).plot(ax = axes[0],label = name[1])
axes[0].legend()
axes[0].set_title('Surface salinity - NA')

salt_cont_NP.sel(time = slice(start_time, end_time)).plot(ax = axes[1],label = name[0])
salt_pram_NP.sel(time = slice(start_time, end_time)).plot(ax = axes[1],label = name[1])
axes[1].legend()
axes[1].set_title('Surface salinity - NP')

salt_cont_SA.sel(time = slice(start_time, end_time)).plot(ax = axes[2],label = name[0])
salt_pram_SA.sel(time = slice(start_time, end_time)).plot(ax = axes[2],label = name[1])
axes[2].legend()
axes[2].set_title('Surface salinity - SA')

salt_cont_SP.sel(time = slice(start_time, end_time)).plot(ax = axes[3],label = name[0])
salt_pram_SP.sel(time = slice(start_time, end_time)).plot(ax = axes[3],label = name[1])
axes[3].legend()
axes[3].set_title('Surface salinity - SP')
# Out:
# Text(0.5, 1.0, 'Surface salinity - SP')

# %% [markdown]
# ## Freshwater fluxes

# %%
pme_river_cont = cc.querying.getvar(expt = expt[0], session = session, variable = 'pme_river', frequency = '1 monthly')
pme_river_pram = cc.querying.getvar(expt = expt[1], session = session, variable = 'pme_river', frequency = '1 monthly', start_time = start_time, end_time = end_time)

# %%
pme_cont_NA = (pme_river_cont*area_t_NA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NA.sum(dim = ['yt_ocean','xt_ocean'])
pme_pram_NA = (pme_river_pram*area_t_NA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NA.sum(dim = ['yt_ocean','xt_ocean'])

pme_cont_NP = (pme_river_cont*area_t_NP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NP.sum(dim = ['yt_ocean','xt_ocean'])
pme_pram_NP = (pme_river_pram*area_t_NP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NP.sum(dim = ['yt_ocean','xt_ocean'])

pme_cont_SA = (pme_river_cont*area_t_SA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SA.sum(dim = ['yt_ocean','xt_ocean'])
pme_pram_SA = (pme_river_pram*area_t_SA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SA.sum(dim = ['yt_ocean','xt_ocean'])

pme_cont_SP = (pme_river_cont*area_t_SP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SP.sum(dim = ['yt_ocean','xt_ocean'])
pme_pram_SP = (pme_river_pram*area_t_SP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SP.sum(dim = ['yt_ocean','xt_ocean'])

# %%
fig, axes = plt.subplots(nrows = 4, figsize = (20,22))

pme_cont_NA.sel(time = slice(start_time, end_time)).plot(ax = axes[0],label = name[0])
pme_pram_NA.sel(time = slice(start_time, end_time)).plot(ax = axes[0],label = name[1])
axes[0].legend()
axes[0].set_title('Freshwater input - NA')

pme_cont_NP.sel(time = slice(start_time, end_time)).plot(ax = axes[1],label = name[0])
pme_pram_NP.sel(time = slice(start_time, end_time)).plot(ax = axes[1],label = name[1])
axes[1].legend()
axes[1].set_title('Freshwater input - NP')

pme_cont_SA.sel(time = slice(start_time, end_time)).plot(ax = axes[2],label = name[0])
pme_pram_SA.sel(time = slice(start_time, end_time)).plot(ax = axes[2],label = name[1])
axes[2].legend()
axes[2].set_title('Freshwater input - SA')

pme_cont_SP.sel(time = slice(start_time, end_time)).plot(ax = axes[3],label = name[0])
pme_pram_SP.sel(time = slice(start_time, end_time)).plot(ax = axes[3],label = name[1])
axes[3].legend()
axes[3].set_title('Freshwater input - SP')
# Out:
# Text(0.5, 1.0, 'Freshwater input - SP')

# %% [markdown]
# ## Surface heat flux

# %%
heat_sfc_cont = cc.querying.getvar(expt = expt[0], session = session, variable = 'net_sfc_heating', frequency = '1 monthly')
heat_sfc_pram = cc.querying.getvar(expt = expt[1], session = session, variable = 'net_sfc_heating', frequency = '1 monthly', 
                                   start_time = start_time, end_time = end_time)

# %%
heat_cont_NA = (heat_sfc_cont*area_t_NA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NA.sum(dim = ['yt_ocean','xt_ocean'])
heat_pram_NA = (heat_sfc_pram*area_t_NA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NA.sum(dim = ['yt_ocean','xt_ocean'])

heat_cont_NP = (heat_sfc_cont*area_t_NP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NP.sum(dim = ['yt_ocean','xt_ocean'])
heat_pram_NP = (heat_sfc_pram*area_t_NP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_NP.sum(dim = ['yt_ocean','xt_ocean'])

heat_cont_SA = (heat_sfc_cont*area_t_SA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SA.sum(dim = ['yt_ocean','xt_ocean'])
heat_pram_SA = (heat_sfc_pram*area_t_SA).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SA.sum(dim = ['yt_ocean','xt_ocean'])

heat_cont_SP = (heat_sfc_cont*area_t_SP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SP.sum(dim = ['yt_ocean','xt_ocean'])
heat_pram_SP = (heat_sfc_pram*area_t_SP).sum(dim = ['yt_ocean','xt_ocean'])/area_t_SP.sum(dim = ['yt_ocean','xt_ocean'])

# %%
fig, axes = plt.subplots(nrows = 4, figsize = (20,22))

heat_cont_NA.sel(time = slice(start_time, end_time)).plot(ax = axes[0],label = name[0])
heat_pram_NA.sel(time = slice(start_time, end_time)).plot(ax = axes[0],label = name[1])
axes[0].legend()
axes[0].set_title('Surface heat flux - NA')

heat_cont_NP.sel(time = slice(start_time, end_time)).plot(ax = axes[1],label = name[0])
heat_pram_NP.sel(time = slice(start_time, end_time)).plot(ax = axes[1],label = name[1])
axes[1].legend()
axes[1].set_title('Surface heat flux - NP')

heat_cont_SA.sel(time = slice(start_time, end_time)).plot(ax = axes[2],label = name[0])
heat_pram_SA.sel(time = slice(start_time, end_time)).plot(ax = axes[2],label = name[1])
axes[2].legend()
axes[2].set_title('Surface heat flux - SA')

heat_cont_SP.sel(time = slice(start_time, end_time)).plot(ax = axes[3],label = name[0])
heat_pram_SP.sel(time = slice(start_time, end_time)).plot(ax = axes[3],label = name[1])
axes[3].legend()
axes[3].set_title('Surface heat flux - SP')
# Out:
# Text(0.5, 1.0, 'Surface heat flux - SP')

# %% [markdown]
# ## Gyre Strength

# %%
tx_trans_int_z_cont = cc.querying.getvar(expt[0], 'tx_trans_int_z', session, start_time = '1990-01-01', end_time = end_time)
ty_trans_int_z_cont = cc.querying.getvar(expt[0], 'ty_trans_int_z', session, start_time = '1990-01-01', end_time = end_time)
tx_trans_int_z_pram = cc.querying.getvar(expt[1], 'tx_trans_int_z', session, start_time = '1990-01-01', end_time = end_time)
ty_trans_int_z_pram = cc.querying.getvar(expt[1], 'ty_trans_int_z', session, start_time = '1990-01-01', end_time = end_time)

# %%
rho0 = 1025

x_min, x_max = -100, 10
y_min, y_max = 20, 75
ty_cont_NA = ty_trans_int_z_cont.sel(xt_ocean = slice(x_min, x_max)).sel(yu_ocean = slice(y_min, y_max))
psi_cont_NA = ty_cont_NA.cumsum('xt_ocean').where(abs(ty_cont_NA<=1.e20))/(rho0*1.e6)
ty_pram_NA = ty_trans_int_z_pram.sel(xt_ocean = slice(x_min, x_max)).sel(yu_ocean = slice(y_min, y_max))
psi_pram_NA = ty_pram_NA.cumsum('xt_ocean').where(abs(ty_pram_NA<=1.e20))/(rho0*1.e6)

x_min, x_max = -250, -100
y_min, y_max = 20, 75
ty_cont_NP = ty_trans_int_z_cont.sel(xt_ocean = slice(x_min, x_max)).sel(yu_ocean = slice(y_min, y_max))
psi_cont_NP = ty_cont_NP.cumsum('xt_ocean').where(abs(ty_cont_NP<=1.e20))/(rho0*1.e6)
ty_pram_NP = ty_trans_int_z_pram.sel(xt_ocean = slice(x_min, x_max)).sel(yu_ocean = slice(y_min, y_max))
psi_pram_NP = ty_pram_NP.cumsum('xt_ocean').where(abs(ty_pram_NP<=1.e20))/(rho0*1.e6)

x_min, x_max = -70, 20
y_min, y_max = -80, -55
tx_cont_SA = tx_trans_int_z_cont.sel(xu_ocean = slice(x_min, x_max)).sel(yt_ocean = slice(y_min, y_max))
psi_cont_SA = tx_cont_SA.cumsum('yt_ocean').where(abs(tx_cont_SA<=1.e20))/(rho0*1.e6)
tx_pram_SA = tx_trans_int_z_pram.sel(xu_ocean = slice(x_min, x_max)).sel(yt_ocean = slice(y_min, y_max))
psi_pram_SA = tx_pram_SA.cumsum('yt_ocean').where(abs(tx_pram_SA<=1.e20))/(rho0*1.e6)

x_min, x_max = -250, -80
y_min, y_max = -80, -55
tx_cont_SP = tx_trans_int_z_cont.sel(xu_ocean = slice(x_min, x_max)).sel(yt_ocean = slice(y_min, y_max))
psi_cont_SP = -tx_cont_SP.cumsum('yt_ocean').where(abs(tx_cont_SP<=1.e20))/(rho0*1.e6)
tx_pram_SP = tx_trans_int_z_pram.sel(xu_ocean = slice(x_min, x_max)).sel(yt_ocean = slice(y_min, y_max))
psi_pram_SP = -tx_pram_SP.cumsum('yt_ocean').where(abs(tx_pram_SP<=1.e20))/(rho0*1.e6)

# %%
start_time_gyre = '1990-01-01'
end_time_gyre = '1999-12-31'
fig, axes = plt.subplots(nrows = 4, ncols = 2, figsize = (28,30))

psi_cont_NA.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[0][0], levels = np.linspace(-20,20,21))
axes[0][0].set_title('Barotropic Streamfunction (NA) - Control Run')

psi_pram_NA.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[0][1], levels = np.linspace(-10,10,21))
axes[0][1].set_title('Barotropic Streamfunction (NA) - Nostress Run')

psi_cont_NP.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[1][0], levels = np.linspace(-20,20,21))
axes[1][0].set_title('Barotropic Streamfunction (NP) - Control Run')

psi_pram_NP.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[1][1], levels = np.linspace(-10,10,21))
axes[1][1].set_title('Barotropic Streamfunction (NP) - Nostress Run')

psi_cont_SA.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[2][0], levels = np.linspace(-50,50,21))
axes[2][0].set_title('Barotropic Streamfunction (SA) - Control Run')

psi_pram_SA.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[2][1], levels = np.linspace(-50,50,21))
axes[2][1].set_title('Barotropic Streamfunction (SA) - Nostress Run')

psi_cont_SP.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[3][0], levels = np.linspace(-30,30,21))
axes[3][0].set_title('Barotropic Streamfunction (SP) - Control Run')

psi_pram_SP.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[3][1], levels = np.linspace(-30,30,21))
axes[3][1].set_title('Barotropic Streamfunction (SP) - Nostress Run')
# Out:
# Text(0.5, 1.0, 'Barotropic Streamfunction (SP) - Nostress Run')

# %%
rho0 = 1025

x_min, x_max = -70, 20
y_min, y_max = -53, -10
ty_cont_SA2 = ty_trans_int_z_cont.sel(xt_ocean = slice(x_min, x_max)).sel(yu_ocean = slice(y_min, y_max))
psi_cont_SA2 = ty_cont_SA2.cumsum('xt_ocean').where(abs(ty_cont_SA2<=1.e20))/(rho0*1.e6)
ty_pram_SA2 = ty_trans_int_z_pram.sel(xt_ocean = slice(x_min, x_max)).sel(yu_ocean = slice(y_min, y_max))
psi_pram_SA2 = ty_pram_SA2.cumsum('xt_ocean').where(abs(ty_pram_SA2<=1.e20))/(rho0*1.e6)

x_min, x_max = -216, -80
y_min, y_max = -35, -15
ty_cont_SP2 = ty_trans_int_z_cont.sel(xt_ocean = slice(x_min, x_max)).sel(yu_ocean = slice(y_min, y_max))
psi_cont_SP2 = -ty_cont_SP2.cumsum('xt_ocean').where(abs(ty_cont_SP2<=1.e20))/(rho0*1.e6)
ty_pram_SP2 = ty_trans_int_z_pram.sel(xt_ocean = slice(x_min, x_max)).sel(yu_ocean = slice(y_min, y_max))
psi_pram_SP2 = -ty_pram_SP2.cumsum('xt_ocean').where(abs(ty_pram_SP2<=1.e20))/(rho0*1.e6)

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (28,15))

psi_cont_SA2.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[0][0], levels = np.linspace(-40,40,21))
axes[0][0].set_title('Barotropic Streamfunction (SA) - Control Run (Subtropical gyre)')

psi_pram_SA2.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[0][1], levels = np.linspace(-40,40,21))
axes[0][1].set_title('Barotropic Streamfunction (SA) - Nostress Run (Subtropical gyre)')

psi_cont_SP2.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[1][0], levels = np.linspace(-10,10,21))
axes[1][0].set_title('Barotropic Streamfunction (SP) - Control Run (Subtropical gyre)')

psi_pram_SP2.sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[1][1], levels = np.linspace(-10,10,21))
axes[1][1].set_title('Barotropic Streamfunction (SP) - Nostress Run (Subtropical gyre)')
# Out:
# Text(0.5, 1.0, 'Barotropic Streamfunction (SP) - Nostress Run (Subtropical gyre)')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (25,15))

(psi_cont_NA - psi_pram_NA).sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[0][0], levels = np.linspace(-20,20,21))
axes[0][0].set_title('Barotropic Streamfunction (NA) - Control - KPP Run')

(psi_cont_NP - psi_pram_NP).sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[0][1], levels = np.linspace(-20,20,21))
axes[0][1].set_title('Barotropic Streamfunction (NP) - Control - KPP Run')

(psi_cont_SA - psi_pram_SA).sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[1][0], levels = np.linspace(-20,20,21))
axes[1][0].set_title('Barotropic Streamfunction (SA) - Control - KPP Run')

(psi_cont_SP - psi_pram_SP).sel(time = slice(start_time_gyre, end_time_gyre)).mean('time').plot.contourf(ax = axes[1][1], levels = np.linspace(-20,20,21))
axes[1][1].set_title('Barotropic Streamfunction (SP) - Control - KPP Run')
# Out:
# Text(0.5, 1.0, 'Barotropic Streamfunction (SP) - Control - KPP Run')

# %% [markdown]
# ## Meridional Overturning Circulation

# %%
psi_cont = cc.querying.getvar(expt[0],'ty_trans_rho', session, start_time = '1999-01-01', end_time = end_time)
psi_cont = psi_cont.sum('grid_xt_ocean')
rho = 1025 # mean density of sea-water in kg/m^3
psi_cont = psi_cont / (1e6*rho) # converts kg/s to Sv
psi_avg_cont = psi_cont.cumsum('potrho').mean('time') - psi_cont.sum('potrho').mean('time')

psi_pram = cc.querying.getvar(expt[1],'ty_trans_rho', session, start_time = '1999-01-01', end_time = end_time)
psi_pram = psi_pram.sum('grid_xt_ocean')
rho = 1025 # mean density of sea-water in kg/m^3
psi_pram = psi_pram / (1e6*rho) # converts kg/s to Sv
psi_avg_pram = psi_pram.cumsum('potrho').mean('time') - psi_pram.sum('potrho').mean('time')

# %%
fig,ax = plt.subplots(1,1,figsize=(10, 5)) 
clev = np.arange(-25,25,2)
yticks = np.array([1030, 1032, 1033, 1034, 1035, 1036,1036.5, 1037])
scfac = 4  ## A power to set teh stretching
p1=ax.contourf(psi_avg_cont.grid_yu_ocean,(psi_avg_cont.potrho-1028)**scfac, psi_avg_cont, cmap=cm.cm.curl, levels=clev, extend='both')
cb=plt.colorbar(p1,orientation='vertical')
    
cb.ax.set_xlabel('Sv')
ax.contour(psi_avg_cont.grid_yu_ocean,(psi_avg_cont.potrho-1028)**scfac, psi_avg_cont, levels=clev, colors='k', linewidths=0.25)
ax.contour(psi_avg_cont.grid_yu_ocean,(psi_avg_cont.potrho-1028)**scfac, psi_avg_cont, levels=[0.0,], colors='k', linewidths=0.5)

ax.set_yticks((yticks-1028)**scfac)
ax.set_yticklabels(yticks)
ax.set_ylim([0.5**scfac, 9.2**scfac])
ax.invert_yaxis()
ax.set_ylabel('Potential Density (kg m$^{-3}$)')
ax.set_xlabel('Latitude ($^\circ$N)')
ax.set_xlim([-75,80])
ax.set_title('Overturning for control run for year 1999');

# %%
fig,ax = plt.subplots(1,1,figsize=(10, 5)) 
clev = np.arange(-25,25,2)
yticks = np.array([1030, 1032, 1033, 1034, 1035, 1036,1036.5, 1037])
scfac = 4  ## A power to set teh stretching
p1=ax.contourf(psi_avg_pram.grid_yu_ocean,(psi_avg_pram.potrho-1028)**scfac, psi_avg_pram, cmap=cm.cm.curl, levels=clev, extend='both')
cb=plt.colorbar(p1,orientation='vertical')
    
cb.ax.set_xlabel('Sv')
ax.contour(psi_avg_pram.grid_yu_ocean,(psi_avg_pram.potrho-1028)**scfac, psi_avg_pram, levels=clev, colors='k', linewidths=0.25)
ax.contour(psi_avg_pram.grid_yu_ocean,(psi_avg_pram.potrho-1028)**scfac, psi_avg_pram, levels=[0.0,], colors='k', linewidths=0.5)

ax.set_yticks((yticks-1028)**scfac)
ax.set_yticklabels(yticks)
ax.set_ylim([0.5**scfac, 9.2**scfac])
ax.invert_yaxis()
ax.set_ylabel('Potential Density (kg m$^{-3}$)')
ax.set_xlabel('Latitude ($^\circ$N)')
ax.set_xlim([-75,80])
ax.set_title('Overturning for nostress run for year 1999');

# %%
fig,ax = plt.subplots(1,1,figsize=(10, 5)) 
clev = np.arange(-25,25,2)
yticks = np.array([1030, 1032, 1033, 1034, 1035, 1036,1036.5, 1037])
scfac = 4  ## A power to set teh stretching
p1 = ax.contourf(psi_avg_cont.grid_yu_ocean,(psi_avg_cont.potrho-1028)**scfac, psi_avg_cont - psi_avg_pram, cmap=cm.cm.curl, levels=clev, extend='both')
cb = plt.colorbar(p1,orientation='vertical')
    
cb.ax.set_xlabel('Sv')
ax.contour(psi_avg_cont.grid_yu_ocean,(psi_avg_cont.potrho-1028)**scfac, psi_avg_cont, levels=clev, colors='k', linewidths=0.25)
ax.contour(psi_avg_cont.grid_yu_ocean,(psi_avg_cont.potrho-1028)**scfac, psi_avg_cont, levels=[0.0,], colors='k', linewidths=0.5)

ax.set_yticks((yticks-1028)**scfac)
ax.set_yticklabels(yticks)
ax.set_ylim([0.5**scfac, 9.2**scfac])
ax.invert_yaxis()
ax.set_ylabel('Potential Density (kg m$^{-3}$)')
ax.set_xlabel('Latitude ($^\circ$N)')
ax.set_xlim([-75,80])
ax.set_title('Overturning for control - parametrised KPP for year 1999');

# %% [markdown]
# ## Global diagnostics

# %%
temp_gave_cont = cc.querying.getvar(expt[0],'temp_global_ave', session, start_time = '1901-01-01', end_time = end_time)
temp_gave_pram = cc.querying.getvar(expt[1],'temp_global_ave', session, start_time = '1901-01-01', end_time = end_time)

salt_gave_cont = cc.querying.getvar(expt[0],'salt_global_ave', session, start_time = '1901-01-01', end_time = end_time)
salt_gave_pram = cc.querying.getvar(expt[1],'salt_global_ave', session, start_time = '1901-01-01', end_time = end_time)

temp_save_cont = cc.querying.getvar(expt[0],'temp_surface_ave', session, start_time = '1901-01-01', end_time = end_time)
temp_save_pram = cc.querying.getvar(expt[1],'temp_surface_ave', session, start_time = '1901-01-01', end_time = end_time)

salt_save_cont = cc.querying.getvar(expt[0],'salt_surface_ave', session, start_time = '1901-01-01', end_time = end_time)
salt_save_pram = cc.querying.getvar(expt[1],'salt_surface_ave', session, start_time = '1901-01-01', end_time = end_time)

ke_tot_cont = cc.querying.getvar(expt[0],'ke_tot', session, start_time = '1901-01-01', end_time = end_time)
ke_tot_pram = cc.querying.getvar(expt[1],'ke_tot', session, start_time = '1901-01-01', end_time = end_time)

pe_tot_cont = cc.querying.getvar(expt[0],'pe_tot', session, start_time = '1901-01-01', end_time = end_time)
pe_tot_pram = cc.querying.getvar(expt[1],'pe_tot', session, start_time = '1901-01-01', end_time = end_time)

# %%
fig, axes = plt.subplots(nrows = 4, figsize = (25,20))

temp_gave_cont.plot(ax = axes[0],label = name[0])
temp_gave_pram.plot(ax = axes[0],label = name[1], ls = '--')
axes[0].legend()
axes[0].set_title('Global temperatuate')

salt_gave_cont.plot(ax = axes[1],label = name[0])
salt_gave_pram.plot(ax = axes[1],label = name[1], ls = '--')
axes[1].legend()
axes[1].set_title('Global salinity')

temp_save_cont.plot(ax = axes[2],label = name[0])
temp_save_pram.plot(ax = axes[2],label = name[1], ls = '--')
axes[2].legend()
axes[2].set_title('Surface temperature')

salt_save_cont.plot(ax = axes[3],label = name[0])
salt_save_pram.plot(ax = axes[3],label = name[1], ls = '--')
axes[3].legend()
axes[3].set_title('Surface salinity')
# Out:
# Text(0.5, 1.0, 'Surface salinity')

# %%
fig, axes = plt.subplots(nrows = 2, figsize = (20,12))

ke_tot_cont.plot(ax = axes[0],label = name[0])
ke_tot_pram.plot(ax = axes[0],label = name[1], ls = '--')
axes[0].legend()
axes[0].set_title('Total KE')

pe_tot_cont.plot(ax = axes[1],label = name[0])
pe_tot_pram.plot(ax = axes[1],label = name[1], ls = '--')
axes[1].legend()
axes[1].set_title('Total PE')
# Out:
# Text(0.5, 1.0, 'Total PE')

# %% [markdown]
# ## Circulation metrics

# %% [markdown]
# ### ACC Transport

# %%
xmin = -69.9
ymin = -71.6
ymax = -51.0
rho0 = 1036

DPtrans_cont = cc.querying.getvar(expt[0], 'tx_trans_int_z', session, start_time = '1901-01-01', end_time = end_time).sel(
    xu_ocean = xmin, method='nearest').sel(yt_ocean = slice(ymin, ymax)).sum('yt_ocean')/rho0/1e6
DPtrans_pram = cc.querying.getvar(expt[1], 'tx_trans_int_z', session, start_time = '1901-01-01', end_time = end_time).sel(
    xu_ocean = xmin, method='nearest').sel(yt_ocean = slice(ymin, ymax)).sum('yt_ocean')/rho0/1e6

# %%
plt.figure(figsize = (20,5))
DPtrans_cont.plot(label = name[0])
DPtrans_pram.plot(label = name[1])
plt.legend()
plt.title('Drake Passage Transport')
# Out:
# Text(0.5, 1.0, 'Drake Passage Transport')

# %% [markdown]
# ### AABW Circulation

# %%
latitude = -55

psi_aabw = cc.querying.getvar(expt[0], 'ty_trans_rho', session, start_time = '1901-01-01', end_time = end_time).sum('grid_xt_ocean').sel(
    method = 'nearest', grid_yu_ocean = latitude)*1.0e-9
psi_aabw_sum = psi_aabw.cumsum('potrho') - psi_aabw.sum('potrho')
psi_aabw_sum_cont = -psi_aabw_sum.sel(potrho = slice(1036.2, None)).min('potrho').resample(time = 'Y').mean()

psi_aabw = cc.querying.getvar(expt[1], 'ty_trans_rho', session, start_time = '1901-01-01', end_time = end_time).sum('grid_xt_ocean').sel(
    method = 'nearest', grid_yu_ocean = latitude)*1.0e-9
psi_aabw_sum = psi_aabw.cumsum('potrho') - psi_aabw.sum('potrho')
psi_aabw_sum_pram = -psi_aabw_sum.sel(potrho = slice(1036.2, None)).min('potrho').resample(time = 'Y').mean()

# %%
plt.figure(figsize = (20,5))
psi_aabw_sum_cont.plot(label = name[0])
psi_aabw_sum_pram.plot(label = name[1])
plt.legend()
plt.title('AABW Circulation')
# Out:
# Text(0.5, 1.0, 'AABW Circulation')

# %% [markdown]
# ### AMOC Cell

# %%
psi_amoc = cc.querying.getvar(expt[0], 'ty_trans_rho', session, start_time = '1901-01-01', end_time = end_time).sel(grid_xt_ocean = slice(-103, -5)).sum(
    'grid_xt_ocean').sel(method = 'Nearest', grid_yu_ocean = 26)*1.0e-9
psi_amoc_sum = psi_amoc.cumsum('potrho') - psi_amoc.sum('potrho')
psi_amoc_sum_cont = psi_amoc_sum.sel(potrho=slice(1035.5,None)).max('potrho').resample(time='Y').mean()

psi_amoc = cc.querying.getvar(expt[1], 'ty_trans_rho', session, start_time = '1901-01-01', end_time = end_time).sel(grid_xt_ocean = slice(-103, -5)).sum(
    'grid_xt_ocean').sel(method = 'Nearest', grid_yu_ocean = 26)*1.0e-9
psi_amoc_sum = psi_amoc.cumsum('potrho') - psi_amoc.sum('potrho')
psi_amoc_sum_pram = psi_amoc_sum.sel(potrho=slice(1035.5,None)).max('potrho').resample(time='Y').mean()

# %%
plt.figure(figsize = (20,5))
psi_amoc_sum_cont.plot(label = name[0])
psi_amoc_sum_pram.plot(label = name[1])
plt.legend()
plt.title('AMOC Cell')
# Out:
# Text(0.5, 1.0, 'AMOC Cell')

# %% [markdown]
# ### Gulf Stream Transport

# %%
xmin = -85
xmax = -75
ymin = 30
rho = 1030

GS_cont = cc.querying.getvar(expt[0], 'ty_trans_int_z', session, start_time = '1901-01-01', end_time = end_time).sel(xt_ocean = slice(xmin, xmax)).sel(
    yu_ocean = ymin, method = 'nearest').sum('xt_ocean')/rho0/1e6
GS_pram = cc.querying.getvar(expt[1], 'ty_trans_int_z', session, start_time = '1901-01-01', end_time = end_time).sel(xt_ocean = slice(xmin, xmax)).sel(
    yu_ocean = ymin, method = 'nearest').sum('xt_ocean')/rho0/1e6

# %%
plt.figure(figsize = (20,5))
GS_cont.plot(label = name[0])
GS_pram.plot(label = name[1])
plt.legend()
plt.title('Gulf Stream Transport')
# Out:
# Text(0.5, 1.0, 'Gulf Stream Transport')

# %% [markdown]
# ### Kuroshio Current

# %%
xmin = -250
xmax = -210
ymin = 30
rho = 1030

KC_cont = cc.querying.getvar(expt[0], 'ty_trans_int_z', session, start_time = '1901-01-01', end_time = end_time).sel(xt_ocean = slice(xmin, xmax)).sel(
    yu_ocean = ymin, method = 'nearest').sum('xt_ocean')/rho0/1e6
KC_pram = cc.querying.getvar(expt[1], 'ty_trans_int_z', session, start_time = '1901-01-01', end_time = end_time).sel(xt_ocean = slice(xmin, xmax)).sel(
    yu_ocean = ymin, method = 'nearest').sum('xt_ocean')/rho0/1e6

# %%
plt.figure(figsize = (20,5))
KC_cont.plot(label = name[0])
KC_pram.plot(label = name[1])
plt.legend()
plt.title('Kuroshio Current')
# Out:
# Text(0.5, 1.0, 'Kuroshio Current')
